# %%
import pandas as pd
import seaborn as sns
import wordcloud

# %%
sns.set()

# %%
import matplotlib
matplotlib.rcParams.update({'font.size': 22})

# %%
# %matplotlib inline

# %%
vehicle_reg = pd.read_csv("VehicleRegisteration.txt")

# %%
vehicle_reg
# Out:
#    Year  No_of_Vehicle
# 0  2008         395435
# 1  2009         414150
# 2  2010         486112
# 3  2011         512988
# 4  2012         529712
# 5  2013         531332
# 6  2014         574602
# 7  2015         430603
# 8  2016         462255

# %%
vehicle_reg.head()
# Out:
#    Year  No_of_Vehicle
# 0  2008         395435
# 1  2009         414150
# 2  2010         486112
# 3  2011         512988
# 4  2012         529712

# %%
vehicle_reg.dtypes
# Out:
# Year             int64
# No_of_Vehicle    int64
# dtype: object

# %%
vehicle_reg.set_index("Year").plot.line(figsize=(15,10))

# %%
year_accidents = pd.read_csv("YearWiseAccidents.txt")

# %%
year_accidents.dtypes
# Out:
# Year                 int64
# Non_Inj_Accidents    int64
# Simple_Accidents     int64
# Fatal_Accidents      int64
# Total_Accidents      int64
# Persons_Injured      int64
# Persons_Killed       int64
# dtype: object

# %%
year_accidents.head(3)
# Out:
#    Year  Non_Inj_Accidents  Simple_Accidents  Fatal_Accidents  \
# 0  2008                362              6058             2015
# 1  2009                131              5113             2272
# 2  2010                 63              5093             2104
#
#    Total_Accidents  Persons_Injured  Persons_Killed
# 0             8435             7343            2093
# 1             7516             6936            2325
# 2             7260             7108            2153

# %%
year_accidents.set_index("Year").plot.line(figsize=(15,10))
